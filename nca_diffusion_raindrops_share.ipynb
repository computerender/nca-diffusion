# %% [markdown]
# # Distilling Stable Diffusion to Neural Cellular Automata
#
# This code is partly adapted from these two files:
# https://github.com/google-research/self-organising-systems/blob/master/notebooks/%CE%BCNCA_pytorch.ipynb
# https://github.com/ashawkey/stable-dreamfusion/blob/main/sd.py

# %%
from pathlib import Path
from datetime import datetime
from contextlib import nullcontext
import random
import torch
from torch import nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
# adapted from https://github.com/ashawkey/stable-dreamfusion/blob/main/sd.py
from stable_diffusion_sds_share import StableDiffusion

# %%
import os
os.environ['FFMPEG_BINARY'] = 'ffmpeg'
import moviepy.editor as mvp
from mediapy import VideoWriter as VW
from moviepy.video.io.ffmpeg_writer import FFMPEG_VideoWriter
from tqdm import tnrange

# %%
device = "cuda" #"cpu"

ctx = nullcontext() # torch.amp.autocast(device_type=device, dtype=torch.bfloat16) #

# %%
def show(t):
    plt.imshow(t.permute(1,2,0).cpu().numpy())

# %%
sd_sds = StableDiffusion(device)
# Out:
# [INFO] loading stable diffusion...
# [INFO] loaded stable diffusion!

# %%
# μNCA 
# adapted from https://github.com/google-research/self-organising-systems/blob/master/notebooks/%CE%BCNCA_pytorch.ipynb

side = torch.tensor([[0.0, 0.0,0.0], [2.0,-2.0,0.0], [0.0, 0.0,0.0]]) 
sobel_x = torch.tensor([[-1.0,0.0,1.0],[-2.0,0.0,2.0],[-1.0,0.0,1.0]]) 
lap = torch.tensor([[1.0,2.0,1.0],[2.0,-12,2.0],[1.0,2.0,1.0]])

# filters = [lap]*2+[sobel_x]*1+[sobel_x.T]*1  # 68 params
# filters = [lap]*2+[sobel_x]*2+[sobel_x.T]*2 # 150 params
# filters = [lap]*4+[sobel_x]*2+[sobel_x.T]*2  # 264 params
#filters = [lap]*4+[sobel_x]*4+[sobel_x.T]*4  # 588 params
filters = [lap]*8+[sobel_x]*4+[sobel_x.T]*8  # 1620 params

filters = torch.stack(filters)[:,None]
filters = filters.to(device)
CHN = len(filters)

class CA(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.randn(CHN, 4*CHN+1, 1, 1)*1e-3)

    def to_rgb(self, x):
        return x[...,:3,:,:]+0.5

    def forward(self, x, update_rate=1.0):
        y = torch.nn.functional.pad(x, [1, 1, 1, 1], 'circular')
        y = torch.nn.functional.conv2d(y, filters, groups=y.shape[1])
        y = torch.cat([x, y], 1)
        y = y = torch.cat([y, y.abs()], 1)
        w, b = self.w[:,:-1], self.w[:,-1,0,0]
        y = torch.nn.functional.conv2d(y, w, b)
        if update_rate<1.0:
            y *= (torch.rand(*y.shape, device=device)+update_rate).floor()
        #return x+y, y
        return y

print('param count:', sum(p.numel() for p in CA().parameters()))
# Out:
# param count: 1620

# %%
def make_vid(out_path, ca, iters, x, y):
    step_n = 1
    with VW(out_path, shape=(x,y)) as w, torch.no_grad():
        s = m_state()["state"]
        for k in range(iters):
            img = ca.to_rgb(s)[0].permute(1,2,0).cpu().numpy()
            #print(img.mean())
            w.add_image(img)
            #print(norm_loss(x, 1))
            for i in range(step_n):
                s = s + ca(s, update_rate=0.5)

# %%
# todo
# 1. increase model capacity
# 2. (done) use pool to reinit from for long term stability
# 3. use simple ca model?
# 4. make memory usage less?
# 5. is quality affected by using fp/bf16?
# 6. increase resolution

def make_state(batch, channels, x, y):
    #return {"state": torch.rand(batch_size, channels, x, y, device=device)-0.5, "steps": 0}
    return {"state": torch.zeros(batch_size, channels, x, y, device=device), "steps": 0}

def norm_loss(cur_img, scale):
    #above = F.relu( cur_img - 1 ) ** 2
    #below = F.relu( -cur_img ) ** 2
    #return scale * (above.mean() + below.mean())
    return scale * ((cur_img - 0.5) ** 2).mean() # for testing for stable loss

batch_size = 1
pool_size = 32
reset_prob = 0.05
ca_steps = 20 #10
channels = 20 #12

iterations = 4000
norm_loss_scale = 10
sd_loss_scale = 0.005

dim = 128 # 256

seed = 0
random.seed(seed)
torch.manual_seed(seed)
ca =  CA().to(device) #  CAModel().to(device)
text_embeds = sd_sds.get_text_embeds(["raindrops on glass"]*batch_size, [""]*batch_size) 
opt = torch.optim.Adam(ca.parameters(), 1e-4)

m_state = lambda : make_state(batch_size, channels, dim, dim)
pool = [m_state() for _ in range(pool_size)]

run_dir = Path("output/{:%Y_%m_%d_%H_%M_%S}".format(datetime.now()))
run_dir.mkdir(exist_ok=True, parents=True)

for i in tnrange(iterations):
    
    track_grad_mag = 0
    track_norm_loss = 0
    loss_steps = 0
    for p in range(pool_size):
        # gradually increase the number of steps a CA is likely 
        # to run so gradients don't explode
        if random.uniform(0, 1) < reset_prob or i < pool[p]["steps"]:
            pool[p] = m_state()
        else:
            pool[p]["state"] = pool[p]["state"].detach()
        state = pool[p]["state"]
        
        for step in range(ca_steps):
            state = state + ca(state, update_rate=0.5)
            
        pixels = ca.to_rgb(state)
        
        with ctx:
            sd_loss, grad_mag = sd_sds.train_step(
                text_embeds, pixels, guidance_scale=200, override_t=None
            )
        
        sd_loss = sd_loss_scale * sd_loss
        loss = sd_loss
        
        # MSE loss for going outside of pixel range
        total_norm_loss = norm_loss(pixels, norm_loss_scale)
        loss += total_norm_loss

        track_norm_loss += total_norm_loss.item()
        track_grad_mag += sd_loss_scale * grad_mag.item()
        loss_steps += 1

        loss.backward()
        pool[p]["state"] = state
        pool[p]["steps"] += ca_steps
        
    print(f"i{i} step{step} grad_mag: {track_grad_mag / loss_steps:06f} " + 
          f"norm loss: {track_norm_loss / loss_steps:06f} " + 
          f"oldest state: {max([s['steps'] for s in pool])}")
    opt.step()
    opt.zero_grad()
    
    # save a video every 10 iterations (this can add up quickly)
    if i % 10 == 0:
        out_dir = run_dir / "states" 
        out_dir.mkdir(exist_ok=True, parents=True)
        path = out_dir / f"run-{i:06d}.mp4"
        make_vid(path, ca, max([p["steps"] for p in pool]), dim, dim)
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
# i0 step19 grad_mag: 0.006064 norm loss: 0.000339 oldest state: 20
# i1 step19 grad_mag: 0.005820 norm loss: 0.000453 oldest state: 20
# i2 step19 grad_mag: 0.008385 norm loss: 0.000594 oldest state: 20
# i3 step19 grad_mag: 0.007729 norm loss: 0.000776 oldest state: 20
# i4 step19 grad_mag: 0.008035 norm loss: 0.001006 oldest state: 20
# i5 step19 grad_mag: 0.009237 norm loss: 0.001299 oldest state: 20
# i6 step19 grad_mag: 0.007377 norm loss: 0.001664 oldest state: 20
# i7 step19 grad_mag: 0.008850 norm loss: 0.002107 oldest state: 20
# i8 step19 grad_mag: 0.006770 norm loss: 0.002651 oldest state: 20
# i9 step19 grad_mag: 0.006065 norm loss: 0.003306 oldest state: 20
# i10 step19 grad_mag: 0.007045 norm loss: 0.004085 oldest state: 20
# i11 step19 grad_mag: 0.003510 norm loss: 0.004993 oldest state: 20
# i12 step19 grad_mag: 0.004306 norm loss: 0.005978 oldest state: 20
# i13 step19 grad_mag: 0.004028 norm loss: 0.007128 oldest state: 20
# i14 step19 grad_mag: 0.004170 norm loss: 0.008475 oldest state: 20
# i15 step19 grad_mag: 0.004380 norm loss: 0.010022 oldest state: 20
# i16 step19 grad_mag: 0.004365 norm loss: 0.011602 oldest state: 20
# i17 step19 grad_mag: 0.004084 norm loss: 0.013132 oldest state: 20
# i18 step19 grad_mag: 0.004782 norm loss: 0.014649 oldest state: 20
# i19 step19 grad_mag: 0.004588 norm loss: 0.016053 oldest state: 20
# i20 step19 grad_mag: 0.006218 norm loss: 0.236708 oldest state: 40
# i21 step19 grad_mag: 0.004383 norm loss: 0.054316 oldest state: 40
# i22 step19 grad_mag: 0.005003 norm loss: 0.281008 oldest state: 40
# i23 step19 grad_mag: 0.004482 norm loss: 0.076661 oldest state: 40
# i24 step19 grad_mag: 0.006038 norm loss: 0.341237 oldest state: 40
# i25 step19 grad_mag: 0.004409 norm loss: 0.089521 oldest state: 40
# i26 step19 grad_mag: 0.005878 norm loss: 0.385614 oldest state: 40
# i27 step19 grad_mag: 0.004707 norm loss: 0.087776 oldest state: 40
# i28 step19 grad_mag: 0.006769 norm loss: 0.458054 oldest state: 40
# i29 step19 grad_mag: 0.005073 norm loss: 0.119434 oldest state: 40
# i30 step19 grad_mag: 0.005880 norm loss: 0.550318 oldest state: 40
# i31 step19 grad_mag: 0.005133 norm loss: 0.155613 oldest state: 40
# i32 step19 grad_mag: 0.006523 norm loss: 0.597405 oldest state: 40
# i33 step19 grad_mag: 0.005270 norm loss: 0.173517 oldest state: 40
# i34 step19 grad_mag: 0.005993 norm loss: 0.571876 oldest state: 40
# i35 step19 grad_mag: 0.005294 norm loss: 0.304207 oldest state: 40
# i36 step19 grad_mag: 0.005628 norm loss: 0.614793 oldest state: 40
# i37 step19 grad_mag: 0.006596 norm loss: 0.405463 oldest state: 40
# i38 step19 grad_mag: 0.005912 norm loss: 0.635501 oldest state: 40
# i39 step19 grad_mag: 0.005613 norm loss: 0.390637 oldest state: 40
# i40 step19 grad_mag: 0.006158 norm loss: 52.615298 oldest state: 60
# i41 step19 grad_mag: 0.004823 norm loss: 98.676664 oldest state: 60
# i42 step19 grad_mag: 0.005109 norm loss: 13.606515 oldest state: 60
# i83 step19 grad_mag: 0.005661 norm loss: 1.601667 oldest state: 100
# i84 step19 grad_mag: 0.004881 norm loss: 0.753445 oldest state: 100
# i85 step19 grad_mag: 0.004252 norm loss: 1.388320 oldest state: 100
# i86 step19 grad_mag: 0.005388 norm loss: 1.615077 oldest state: 100
# i87 step19 grad_mag: 0.005462 norm loss: 1.228675 oldest state: 100
# i88 step19 grad_mag: 0.005008 norm loss: 1.428045 oldest state: 100
# i89 step19 grad_mag: 0.004956 norm loss: 0.666072 oldest state: 100
# i90 step19 grad_mag: 0.004734 norm loss: 1.165631 oldest state: 100
# i91 step19 grad_mag: 0.005284 norm loss: 1.576856 oldest state: 100
# i92 step19 grad_mag: 0.004496 norm loss: 0.818112 oldest state: 100
# i93 step19 grad_mag: 0.004699 norm loss: 1.038564 oldest state: 100
# i94 step19 grad_mag: 0.004250 norm loss: 0.622709 oldest state: 100
# i95 step19 grad_mag: 0.005442 norm loss: 0.942933 oldest state: 100
# i96 step19 grad_mag: 0.005549 norm loss: 1.317081 oldest state: 100
# i97 step19 grad_mag: 0.005228 norm loss: 0.877346 oldest state: 100
# i98 step19 grad_mag: 0.004967 norm loss: 0.920752 oldest state: 100
# i99 step19 grad_mag: 0.004718 norm loss: 0.472658 oldest state: 100
# i100 step19 grad_mag: 0.005185 norm loss: 1.720010 oldest state: 120
# i101 step19 grad_mag: 0.006254 norm loss: 2.245524 oldest state: 120
# i102 step19 grad_mag: 0.005025 norm loss: 3.245373 oldest state: 120
# i103 step19 grad_mag: 0.004484 norm loss: 2.428652 oldest state: 120
# i104 step19 grad_mag: 0.005556 norm loss: 2.341553 oldest state: 120
# i105 step19 grad_mag: 0.005327 norm loss: 0.625985 oldest state: 120
# i106 step19 grad_mag: 0.006372 norm loss: 1.236610 oldest state: 120
# i107 step19 grad_mag: 0.006344 norm loss: 1.145608 oldest state: 120
# i108 step19 grad_mag: 0.006368 norm loss: 1.186755 oldest state: 120
# i109 step19 grad_mag: 0.005089 norm loss: 1.096894 oldest state: 120
# i110 step19 grad_mag: 0.004699 norm loss: 0.862137 oldest state: 120
# i111 step19 grad_mag: 0.006034 norm loss: 0.604731 oldest state: 120
# i112 step19 grad_mag: 0.007265 norm loss: 0.964867 oldest state: 120
# i113 step19 grad_mag: 0.005800 norm loss: 0.843824 oldest state: 120
# i114 step19 grad_mag: 0.005785 norm loss: 0.887342 oldest state: 120
# i115 step19 grad_mag: 0.005292 norm loss: 0.784230 oldest state: 120
# i116 step19 grad_mag: 0.006709 norm loss: 0.578562 oldest state: 120
# i117 step19 grad_mag: 0.005719 norm loss: 0.560143 oldest state: 120
# i118 step19 grad_mag: 0.006187 norm loss: 0.750189 oldest state: 120
# i119 step19 grad_mag: 0.005921 norm loss: 0.607562 oldest state: 120
# i120 step19 grad_mag: 0.007010 norm loss: 1.610830 oldest state: 140
# i121 step19 grad_mag: 0.007196 norm loss: 2.315698 oldest state: 140
# i122 step19 grad_mag: 0.005504 norm loss: 1.420787 oldest state: 140
# i123 step19 grad_mag: 0.006965 norm loss: 1.101971 oldest state: 140
# i124 step19 grad_mag: 0.005750 norm loss: 1.035020 oldest state: 140
# i125 step19 grad_mag: 0.006908 norm loss: 1.289358 oldest state: 140
# i126 step19 grad_mag: 0.007402 norm loss: 1.097028 oldest state: 140
# i127 step19 grad_mag: 0.006340 norm loss: 1.723640 oldest state: 140
# i128 step19 grad_mag: 0.006212 norm loss: 1.405508 oldest state: 140
# i129 step19 grad_mag: 0.005825 norm loss: 1.036977 oldest state: 140
# i130 step19 grad_mag: 0.007218 norm loss: 0.681714 oldest state: 140
# i131 step19 grad_mag: 0.006672 norm loss: 0.862096 oldest state: 140
# i132 step19 grad_mag: 0.005938 norm loss: 0.718670 oldest state: 140
# i133 step19 grad_mag: 0.005754 norm loss: 0.736682 oldest state: 140
# i134 step19 grad_mag: 0.007578 norm loss: 1.007849 oldest state: 140
# i135 step19 grad_mag: 0.006184 norm loss: 0.824249 oldest state: 140
# i136 step19 grad_mag: 0.006600 norm loss: 0.583538 oldest state: 140
# i137 step19 grad_mag: 0.006548 norm loss: 0.751056 oldest state: 140
# i138 step19 grad_mag: 0.007286 norm loss: 0.818647 oldest state: 140
# i139 step19 grad_mag: 0.006001 norm loss: 0.624772 oldest state: 140
# i140 step19 grad_mag: 0.008286 norm loss: 1.308787 oldest state: 160
# i141 step19 grad_mag: 0.007652 norm loss: 1.337899 oldest state: 160
# i142 step19 grad_mag: 0.007131 norm loss: 2.073020 oldest state: 160
# i143 step19 grad_mag: 0.005874 norm loss: 1.894868 oldest state: 160
# i144 step19 grad_mag: 0.007023 norm loss: 1.512055 oldest state: 160
# i145 step19 grad_mag: 0.005710 norm loss: 1.394126 oldest state: 160
# i146 step19 grad_mag: 0.005703 norm loss: 2.129899 oldest state: 160
# i147 step19 grad_mag: 0.006385 norm loss: 1.458709 oldest state: 160
# i148 step19 grad_mag: 0.005422 norm loss: 1.756024 oldest state: 160
# i149 step19 grad_mag: 0.006467 norm loss: 2.183498 oldest state: 160
# i150 step19 grad_mag: 0.007338 norm loss: 3.214790 oldest state: 160
# i151 step19 grad_mag: 0.005704 norm loss: 2.099157 oldest state: 160
# i152 step19 grad_mag: 0.005423 norm loss: 1.166138 oldest state: 160
# i153 step19 grad_mag: 0.006361 norm loss: 0.881471 oldest state: 160
# i154 step19 grad_mag: 0.005976 norm loss: 0.875306 oldest state: 160
# i155 step19 grad_mag: 0.005536 norm loss: 0.619698 oldest state: 140
# i156 step19 grad_mag: 0.007721 norm loss: 0.829187 oldest state: 160
# i157 step19 grad_mag: 0.007143 norm loss: 0.775610 oldest state: 160
# i158 step19 grad_mag: 0.008882 norm loss: 0.839029 oldest state: 160
# i159 step19 grad_mag: 0.006156 norm loss: 0.539960 oldest state: 160
# i160 step19 grad_mag: 0.006503 norm loss: 1.437507 oldest state: 180
# i161 step19 grad_mag: 0.005736 norm loss: 0.869062 oldest state: 180
# i162 step19 grad_mag: 0.007366 norm loss: 0.993963 oldest state: 180
# i163 step19 grad_mag: 0.005827 norm loss: 1.455394 oldest state: 180
# i164 step19 grad_mag: 0.006599 norm loss: 1.014072 oldest state: 160
# i165 step19 grad_mag: 0.006550 norm loss: 2.188789 oldest state: 180
# i166 step19 grad_mag: 0.005596 norm loss: 2.717797 oldest state: 180
# i167 step19 grad_mag: 0.006109 norm loss: 2.905488 oldest state: 180
# i168 step19 grad_mag: 0.005353 norm loss: 1.594173 oldest state: 180
# i169 step19 grad_mag: 0.005543 norm loss: 2.318307 oldest state: 180
# i170 step19 grad_mag: 0.005782 norm loss: 2.371072 oldest state: 180
# i171 step19 grad_mag: 0.006425 norm loss: 2.825238 oldest state: 180
# i172 step19 grad_mag: 0.006018 norm loss: 1.940564 oldest state: 180
# i173 step19 grad_mag: 0.006873 norm loss: 2.473132 oldest state: 180
# i174 step19 grad_mag: 0.005710 norm loss: 2.877676 oldest state: 180
# i175 step19 grad_mag: 0.006246 norm loss: 1.672579 oldest state: 180
# i176 step19 grad_mag: 0.005626 norm loss: 1.063618 oldest state: 180
# i177 step19 grad_mag: 0.006104 norm loss: 0.460640 oldest state: 160
# i178 step19 grad_mag: 0.006857 norm loss: 0.598078 oldest state: 180
# i179 step19 grad_mag: 0.006874 norm loss: 0.462786 oldest state: 180
# i180 step19 grad_mag: 0.007713 norm loss: 0.773042 oldest state: 200
# i181 step19 grad_mag: 0.006560 norm loss: 0.778727 oldest state: 200
# i182 step19 grad_mag: 0.007934 norm loss: 0.529847 oldest state: 200
# i183 step19 grad_mag: 0.005552 norm loss: 0.816126 oldest state: 200
# i184 step19 grad_mag: 0.006352 norm loss: 0.765710 oldest state: 200
# i185 step19 grad_mag: 0.007221 norm loss: 0.634623 oldest state: 200
# i186 step19 grad_mag: 0.007502 norm loss: 0.602488 oldest state: 200
# i187 step19 grad_mag: 0.006841 norm loss: 0.778000 oldest state: 200
# i188 step19 grad_mag: 0.007484 norm loss: 1.393394 oldest state: 200
# i189 step19 grad_mag: 0.006491 norm loss: 1.362633 oldest state: 200
# i190 step19 grad_mag: 0.005948 norm loss: 2.237395 oldest state: 200
# i191 step19 grad_mag: 0.006829 norm loss: 2.709785 oldest state: 200
# i192 step19 grad_mag: 0.005745 norm loss: 2.873705 oldest state: 200
# i193 step19 grad_mag: 0.006925 norm loss: 4.023926 oldest state: 200
# i194 step19 grad_mag: 0.006594 norm loss: 3.468050 oldest state: 200
# i195 step19 grad_mag: 0.005821 norm loss: 4.286251 oldest state: 200
# i196 step19 grad_mag: 0.006867 norm loss: 3.723853 oldest state: 200
# i197 step19 grad_mag: 0.005837 norm loss: 2.271853 oldest state: 200
# i198 step19 grad_mag: 0.006707 norm loss: 2.914605 oldest state: 200
# i199 step19 grad_mag: 0.004777 norm loss: 2.292601 oldest state: 200
# i200 step19 grad_mag: 0.006220 norm loss: 4.345044 oldest state: 220
# i201 step19 grad_mag: 0.006188 norm loss: 2.811899 oldest state: 220
# i281 step19 grad_mag: 0.005438 norm loss: 7.770196 oldest state: 300
# i282 step19 grad_mag: 0.005176 norm loss: 5.522431 oldest state: 280
# i283 step19 grad_mag: 0.006437 norm loss: 8.228251 oldest state: 300
# i284 step19 grad_mag: 0.006515 norm loss: 4.290172 oldest state: 300
# i285 step19 grad_mag: 0.006023 norm loss: 3.731985 oldest state: 280
# i286 step19 grad_mag: 0.005898 norm loss: 4.895684 oldest state: 300
# i287 step19 grad_mag: 0.006289 norm loss: 4.772858 oldest state: 300
# i288 step19 grad_mag: 0.004664 norm loss: 2.966567 oldest state: 300
# i289 step19 grad_mag: 0.005815 norm loss: 2.289325 oldest state: 300
# i290 step19 grad_mag: 0.005028 norm loss: 1.414874 oldest state: 300
# i291 step19 grad_mag: 0.004753 norm loss: 0.665059 oldest state: 280
# i292 step19 grad_mag: 0.005579 norm loss: 0.746258 oldest state: 300
# i293 step19 grad_mag: 0.005521 norm loss: 0.546678 oldest state: 300
# i294 step19 grad_mag: 0.006098 norm loss: 0.464031 oldest state: 280
# i295 step19 grad_mag: 0.005188 norm loss: 0.600190 oldest state: 300
# i296 step19 grad_mag: 0.005137 norm loss: 0.688837 oldest state: 300
# i297 step19 grad_mag: 0.005254 norm loss: 0.666806 oldest state: 280
# i298 step19 grad_mag: 0.005200 norm loss: 0.737947 oldest state: 300
# i299 step19 grad_mag: 0.006133 norm loss: 0.735504 oldest state: 300
# i300 step19 grad_mag: 0.004956 norm loss: 0.920128 oldest state: 320
# i301 step19 grad_mag: 0.005230 norm loss: 0.946324 oldest state: 300
# i302 step19 grad_mag: 0.004880 norm loss: 1.180058 oldest state: 320
# i303 step19 grad_mag: 0.005847 norm loss: 1.288037 oldest state: 320
# i304 step19 grad_mag: 0.004682 norm loss: 1.126569 oldest state: 320
# i305 step19 grad_mag: 0.005547 norm loss: 1.231681 oldest state: 320
# i306 step19 grad_mag: 0.005420 norm loss: 1.152134 oldest state: 320
# i307 step19 grad_mag: 0.005032 norm loss: 1.020832 oldest state: 320
# i308 step19 grad_mag: 0.006154 norm loss: 0.963558 oldest state: 320
# i309 step19 grad_mag: 0.005964 norm loss: 0.600081 oldest state: 320
# i310 step19 grad_mag: 0.005371 norm loss: 0.481444 oldest state: 260
# i311 step19 grad_mag: 0.005593 norm loss: 0.611632 oldest state: 280
# i312 step19 grad_mag: 0.005612 norm loss: 0.772044 oldest state: 300
# i313 step19 grad_mag: 0.005154 norm loss: 1.012253 oldest state: 320
# i314 step19 grad_mag: 0.006109 norm loss: 1.211792 oldest state: 320
# i315 step19 grad_mag: 0.005087 norm loss: 1.237280 oldest state: 300
# i316 step19 grad_mag: 0.005474 norm loss: 1.479098 oldest state: 300
# i317 step19 grad_mag: 0.005839 norm loss: 1.937633 oldest state: 320
# i318 step19 grad_mag: 0.005958 norm loss: 1.558590 oldest state: 320
# i319 step19 grad_mag: 0.004931 norm loss: 1.024103 oldest state: 300
# i320 step19 grad_mag: 0.005565 norm loss: 1.395026 oldest state: 320
# i1259 step19 grad_mag: 0.007156 norm loss: 0.977733 oldest state: 960
# i1260 step19 grad_mag: 0.007143 norm loss: 0.987573 oldest state: 980
# i1261 step19 grad_mag: 0.006269 norm loss: 1.038529 oldest state: 1000
# i1262 step19 grad_mag: 0.006159 norm loss: 1.032599 oldest state: 1020
# i1263 step19 grad_mag: 0.006728 norm loss: 1.091120 oldest state: 1040
# i1264 step19 grad_mag: 0.006319 norm loss: 1.143934 oldest state: 1060
# i1265 step19 grad_mag: 0.006613 norm loss: 1.188497 oldest state: 1080
# i1266 step19 grad_mag: 0.006399 norm loss: 1.153914 oldest state: 1100
# i1267 step19 grad_mag: 0.006128 norm loss: 1.231623 oldest state: 1120
# i1268 step19 grad_mag: 0.006729 norm loss: 1.247181 oldest state: 1140
# i1269 step19 grad_mag: 0.006229 norm loss: 1.324678 oldest state: 1160
# i1270 step19 grad_mag: 0.005954 norm loss: 1.361469 oldest state: 1180
# i1271 step19 grad_mag: 0.006233 norm loss: 1.392928 oldest state: 1200
# i1272 step19 grad_mag: 0.006343 norm loss: 1.296831 oldest state: 1220
# i1273 step19 grad_mag: 0.005910 norm loss: 1.272005 oldest state: 1160

# %%
show(ca.to_rgb(state)[0].detach())

# %%
ca.to_rgb(state)[0].mean()

# %%
class VideoWriter:
    def __init__(self, filename="_autoplay.mp4", fps=30.0, **kw):
        self.writer = None
        self.params = dict(filename=filename, fps=fps, **kw)

    def add(self, img):
        img = np.asarray(img)
        if self.writer is None:
            h, w = img.shape[:2]
            self.writer = FFMPEG_VideoWriter(size=(w, h), **self.params)
        if img.dtype in [np.float32, np.float64]:
            img = np.uint8(img.clip(0, 1) * 255)
        if len(img.shape) == 2:
            img = np.repeat(img[..., None], 3, -1)
        self.writer.write_frame(img)

    def close(self):
        if self.writer:
            self.writer.close()

    def __enter__(self):
        return self

    def __exit__(self, *kw):
        self.close()
        if self.params["filename"] == "_autoplay.mp4":
            self.show()

    def show(self, **kw):
        self.close()
        fn = self.params["filename"]
        display(mvp.ipython_display(fn, **kw))


class LoopWriter(VideoWriter):
    def __init__(self, *a, fade_len=1.0, **kw):
        super().__init__(*a, **kw)
        self._intro = []
        self._outro = []
        self.fade_len = int(fade_len * self.params["fps"])

    def add(self, img):
        if len(self._intro) < self.fade_len:
            self._intro.append(img)
            return
        self._outro.append(img)
        if len(self._outro) > self.fade_len:
            super().add(self._outro.pop(0))

    def close(self):
        for t in np.linspace(0, 1, len(self._intro)):
            img = self._intro.pop(0) * t + self._outro.pop(0) * (1.0 - t)
            super().add(img)
        super().close()

# %%
step_n = 1

with LoopWriter('final_ca.mp4', fade_len=0.0) as vid, torch.no_grad():
    x = make_state(1, 20, 512, 512)["state"] #m_state()["state"]
    for k in tnrange(200, leave=False):
        img = ca.to_rgb(x)[0].detach().permute(1,2,0).cpu().numpy()
        img = np.dot(img, [0.2989, 0.5870, 0.1140])
        vid.add(img)
        #print(norm_loss(x, 1))
        for i in range(step_n):
            x = x + ca(x, update_rate=0.5)
vid.show()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
