# %%
from pathlib import Path
from datetime import datetime
import random
import torch
from torch import nn
import torch.nn.functional as F
from stable_diffusion_sds import StableDiffusion
import matplotlib.pyplot as plt
from tqdm import tqdm
from einops import reduce
from PIL import Image
import numpy as np
# Out:
# /home/pwhiddy/mambaforge-pypy3/envs/py10/lib/python3.10/site-packages/flax/core/frozen_dict.py:169: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(

# %%
import os
os.environ['FFMPEG_BINARY'] = 'ffmpeg'
import moviepy.editor as mvp
from moviepy.video.io.ffmpeg_writer import FFMPEG_VideoWriter
from tqdm import tqdm_notebook, tnrange

# %%
#!pip install kornia
import kornia

# %%
device = "cuda"#"cpu"

# %%
def show(t):
    plt.imshow(t.permute(1,2,0).cpu().numpy())

# %%
sd_sds = StableDiffusion(device)
# Out:
# [INFO] loading stable diffusion...
# [INFO] loaded stable diffusion!

# %%
# μNCA 
# from https://github.com/google-research/self-organising-systems/blob/master/notebooks/%CE%BCNCA_pytorch.ipynb

side = torch.tensor([[0.0, 0.0,0.0], [2.0,-2.0,0.0], [0.0, 0.0,0.0]]) 
sobel_x = torch.tensor([[-1.0,0.0,1.0],[-2.0,0.0,2.0],[-1.0,0.0,1.0]]) 
lap = torch.tensor([[1.0,2.0,1.0],[2.0,-12,2.0],[1.0,2.0,1.0]])

# filters = [lap]*2+[sobel_x]*1+[sobel_x.T]*1  # 68 params
# filters = [lap]*2+[sobel_x]*2+[sobel_x.T]*2 # 150 params
# filters = [lap]*4+[sobel_x]*2+[sobel_x.T]*2  # 264 params
filters = [lap]*4+[sobel_x]*4+[sobel_x.T]*4  # 588 params

filters = torch.stack(filters)[:,None]
filters = filters.to(device)
CHN = len(filters)

class CA(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.randn(CHN, 4*CHN+1, 1, 1)*1e-3)

    def to_rgb(self, x):
        return x[...,:3,:,:]+0.5

    def forward(self, x, update_rate=1.0):
        y = torch.nn.functional.pad(x, [1, 1, 1, 1], 'circular')
        y = torch.nn.functional.conv2d(y, filters, groups=y.shape[1])
        y = torch.cat([x, y], 1)
        y = y = torch.cat([y, y.abs()], 1)
        #y = torch.cat([y.relu(), -(-y).relu()], 1)
        w, b = self.w[:,:-1], self.w[:,-1,0,0]
        y = torch.nn.functional.conv2d(y, w, b)
        if update_rate<1.0:
            y *= (torch.rand(*y.shape)+update_rate).floor()
        #return x+y, y
        return y
    
def seed_f(n, sz=128):
    return torch.rand(n, CHN, sz, sz)-0.5

ca = CA().to(device)
print('param count:', sum(p.numel() for p in ca.parameters()))
# Out:
# param count: 588

# %%
# regular nca, implementation from: https://github.com/PWhiddy/Growing-Neural-Cellular-Automata-Pytorch/blob/master/CA_Particles_V3/ca_particles/ca_model.py
# from 
class CAModel(nn.Module):
    
    def __init__(self, env_d, hidden_d, device):
        super(CAModel, self).__init__()
        self.env_d = env_d
        self.conv1 = nn.Conv2d(env_d*3, hidden_d, 1).to(device)
        self.conv2 = nn.Conv2d(hidden_d, env_d, 1).to(device)
        nn.init.zeros_(self.conv2.weight)
        nn.init.zeros_(self.conv2.bias)
        
    def forward(self, x):
        x = F.relu(self.conv1(x))
        return self.conv2(x)

    def to_rgb(self, x):
        return x[...,:3,:,:]+0.5

# %%
def np2pil(a):
    if a.dtype in [np.float32, np.float64]:
        a = np.uint8(np.clip(a, 0, 1)*255)
    return Image.fromarray(a)

# %%
#print(torch.cuda.memory_summary())

# %%
# %%script false --no-raise-error
# # dummy img training (random t)
# init_img = torch.rand(1,3,512,512, device=device, requires_grad=True)
# init_img.mean()
# text_embeds = sd_sds.get_text_embeds(["raindrops on glass"]*batch_size, [""]*batch_size)
# opt_t = torch.optim.SGD([init_img], 0.2) #torch.optim.Adam([init_img], 0.1)
# for i in tqdm(range(950)):
#     # timestep ~ U(0.02, 0.98) to avoid very high/low noise level
#     override_t = None#torch.tensor([975-i], dtype=torch.long, device=device)
#     loss, grad_mag = sd_sds.train_step(text_embeds, init_img, guidance_scale=50, override_t=override_t)
#     loss = loss
#     loss.backward()
#     opt_t.step()
#     opt_t.zero_grad()
# result = init_img[0].detach()
# show(result)

# %%
torch.clip(torch.tensor([0.4]), 0.5, 1)
# Out:
# tensor([0.5000])

# %%
# todo
# 1. increase model capacity
# 2. use pool to reinit from for long term stability
# 3. use simple ca model?
# 4. make memory usage less?
# 5. increase resolution

def make_state(batch, channels, x, y):
    #return {"state": torch.rand(batch_size, channels, x, y, device=device)-0.5, "steps": 0}
    s = torch.zeros(batch_size, channels, x, y, device=device)-0.5
    s[:, :, x//2, y//2] = 0.5
    return {"state": s, "steps": 0}

def norm_loss(cur_img, scale):
    #above = F.relu( cur_img - 1 ) ** 2
    #below = F.relu( -cur_img ) ** 2
    #return scale * (above.mean() + below.mean())
    return scale * ((cur_img - 0.5) ** 2).mean() # for testing for stable loss

torch.manual_seed(120)
ca =  CA().to(device) #  CAModel().to(device)
batch_size = 1
pool_size = 32
reset_prob = 0.05
m_state = lambda : make_state(batch_size, 12, 128, 128)
pool = [m_state() for _ in range(pool_size)]
# gorgeous rainforrest brush |  water ripples from above | "red hot lava" | ripples moving out from a drop of water in clear blue, viewed from above
text_embeds = sd_sds.get_text_embeds(["raindrops on glass"]*batch_size, [""]*batch_size) 
opt = torch.optim.Adam(ca.parameters(), 1e-3)
ca_steps = 20
iterations = 6000
norm_loss_scale = 10
sd_loss_scale = 0.001 #0.00005
run_dir = Path("output/{:%Y_%m_%d_%H_%M_%S}".format(datetime.now()))
run_dir.mkdir(exist_ok=True, parents=True)
#res = torch.zeros(3, 32*5,32*5)
for i in tnrange(iterations):
    
    track_grad_mag = 0
    track_norm_loss = 0
    loss_steps = 0
    for p in range(pool_size):
        if random.uniform(0, 1) < reset_prob or i < pool[p]["steps"]:
            pool[p] = m_state()
        else:
            pool[p]["state"] = pool[p]["state"].detach()
        state = pool[p]["state"]
        
        for step in range(ca_steps):
            state = state + ca(state)
            
        sd_loss, grad_mag = sd_sds.train_step(text_embeds, ca.to_rgb(state), guidance_scale=200, override_t=None)
        time_sd_loss_scale = min(1, 0.005*i) ** 2
        sd_loss = time_sd_loss_scale * sd_loss_scale * sd_loss

        # similar to MSE loss for going outside of range
        # https://www.desmos.com/calculator/74bzpyt0ho
        cur_img = ca.to_rgb(state)
        total_norm_loss = norm_loss(cur_img, norm_loss_scale)

        track_norm_loss += total_norm_loss.item()
        track_grad_mag += time_sd_loss_scale * sd_loss_scale * grad_mag.item()
        loss_steps += 1

        loss = sd_loss
        loss += total_norm_loss

        loss.backward()
        pool[p]["state"] = state
        pool[p]["steps"] += ca_steps
        
    print(f"i{i} step{step} grad_mag: {track_grad_mag / loss_steps:06f} norm loss: {track_norm_loss / loss_steps:06f} oldest state: {max([s['steps'] for s in pool])}")
    opt.step()
    opt.zero_grad()
    
    if i % 10 == 0:
        #small = reduce(result, "c (h a) (w b) -> c h w", "mean", a=16, b=16)
        out_dir = run_dir / "states" 
        out_dir.mkdir(exist_ok=True, parents=True)
        path = out_dir / f"state-{i:06d}.jpg"
        np2pil(ca.to_rgb(pool[0]["state"])[0].detach().permute(1,2,0).cpu().numpy()).save(path)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# i0 step19 grad_mag: 0.000000 norm loss: 2.188672 oldest state: 20
# i1 step19 grad_mag: 0.000273 norm loss: 0.390217 oldest state: 20
# i2 step19 grad_mag: 0.001500 norm loss: 0.074955 oldest state: 20
# i3 step19 grad_mag: 0.003390 norm loss: 0.564858 oldest state: 20
# i4 step19 grad_mag: 0.005474 norm loss: 0.442759 oldest state: 20
# i5 step19 grad_mag: 0.005056 norm loss: 0.159118 oldest state: 20
# i6 step19 grad_mag: 0.008946 norm loss: 0.020747 oldest state: 20
# i7 step19 grad_mag: 0.013269 norm loss: 0.007818 oldest state: 20
# i8 step19 grad_mag: 0.017806 norm loss: 0.043868 oldest state: 20
# i9 step19 grad_mag: 0.020567 norm loss: 0.083728 oldest state: 20
# i10 step19 grad_mag: 0.038897 norm loss: 0.108526 oldest state: 20
# i11 step19 grad_mag: 0.033834 norm loss: 0.114437 oldest state: 20
# i12 step19 grad_mag: 0.039163 norm loss: 0.104395 oldest state: 20
# i13 step19 grad_mag: 0.043790 norm loss: 0.084338 oldest state: 20
# i14 step19 grad_mag: 0.070230 norm loss: 0.060393 oldest state: 20
# i15 step19 grad_mag: 0.056548 norm loss: 0.037567 oldest state: 20
# i16 step19 grad_mag: 0.096440 norm loss: 0.019344 oldest state: 20
# i17 step19 grad_mag: 0.070491 norm loss: 0.007732 oldest state: 20
# i18 step19 grad_mag: 0.105792 norm loss: 0.003003 oldest state: 20
# i19 step19 grad_mag: 0.102797 norm loss: 0.004279 oldest state: 20
# i20 step19 grad_mag: 0.172050 norm loss: 0.796689 oldest state: 40
# i21 step19 grad_mag: 0.166101 norm loss: 0.079231 oldest state: 40
# i22 step19 grad_mag: 0.266544 norm loss: 0.391503 oldest state: 40
# i23 step19 grad_mag: 0.215557 norm loss: 0.057597 oldest state: 40
# i24 step19 grad_mag: 0.147122 norm loss: 0.060747 oldest state: 40
# i25 step19 grad_mag: 0.202982 norm loss: 0.015233 oldest state: 40
# i26 step19 grad_mag: 0.329922 norm loss: 0.016587 oldest state: 40
# i27 step19 grad_mag: 0.230930 norm loss: 0.035953 oldest state: 40
# i28 step19 grad_mag: 0.396005 norm loss: 0.055042 oldest state: 40
# i29 step19 grad_mag: 0.291217 norm loss: 0.060022 oldest state: 40
# i30 step19 grad_mag: 0.415310 norm loss: 0.079258 oldest state: 40
# i31 step19 grad_mag: 0.423544 norm loss: 0.059360 oldest state: 40
# i32 step19 grad_mag: 0.356765 norm loss: 0.061710 oldest state: 40
# i33 step19 grad_mag: 0.371494 norm loss: 0.036787 oldest state: 40
# i34 step19 grad_mag: 0.424471 norm loss: 0.033756 oldest state: 40
# i35 step19 grad_mag: 0.466776 norm loss: 0.015834 oldest state: 40
# i36 step19 grad_mag: 0.452261 norm loss: 0.012130 oldest state: 40
# i37 step19 grad_mag: 0.546259 norm loss: 0.007195 oldest state: 40
# i38 step19 grad_mag: 0.604521 norm loss: 0.012290 oldest state: 40
# i39 step19 grad_mag: 0.585663 norm loss: 0.013309 oldest state: 40
# i40 step19 grad_mag: 0.821449 norm loss: 0.156114 oldest state: 60
# i41 step19 grad_mag: 0.721412 norm loss: 0.267296 oldest state: 60
# i42 step19 grad_mag: 0.850461 norm loss: 0.062344 oldest state: 60
# i43 step19 grad_mag: 0.521404 norm loss: 0.040434 oldest state: 60
# i44 step19 grad_mag: 0.740153 norm loss: 0.050864 oldest state: 60
# i45 step19 grad_mag: 0.563178 norm loss: 0.025225 oldest state: 60
# i46 step19 grad_mag: 0.747203 norm loss: 0.027835 oldest state: 60
# i47 step19 grad_mag: 0.621095 norm loss: 0.034230 oldest state: 60
# i48 step19 grad_mag: 0.820583 norm loss: 0.032901 oldest state: 60
# i49 step19 grad_mag: 0.951385 norm loss: 0.038230 oldest state: 60
# i50 step19 grad_mag: 1.076186 norm loss: 0.083185 oldest state: 60
# i51 step19 grad_mag: 1.355704 norm loss: 0.077388 oldest state: 60
# i52 step19 grad_mag: 1.181910 norm loss: 0.072700 oldest state: 60
# i53 step19 grad_mag: 1.280880 norm loss: 0.054806 oldest state: 60
# i54 step19 grad_mag: 1.046535 norm loss: 0.034206 oldest state: 60
# i55 step19 grad_mag: 1.305401 norm loss: 0.031618 oldest state: 60
# i56 step19 grad_mag: 1.115276 norm loss: 0.035268 oldest state: 60
# i57 step19 grad_mag: 1.228820 norm loss: 0.028999 oldest state: 60
# i58 step19 grad_mag: 1.307042 norm loss: 0.028495 oldest state: 60
# i59 step19 grad_mag: 1.369944 norm loss: 0.034566 oldest state: 60
# i60 step19 grad_mag: 1.955253 norm loss: 0.157350 oldest state: 80
# i61 step19 grad_mag: 1.586204 norm loss: 0.191606 oldest state: 80
# i62 step19 grad_mag: 1.917178 norm loss: 0.158672 oldest state: 80
# i63 step19 grad_mag: 1.585743 norm loss: 0.012975 oldest state: 80
# i64 step19 grad_mag: 2.151335 norm loss: 0.017176 oldest state: 80
# i65 step19 grad_mag: 1.812201 norm loss: 0.030364 oldest state: 80
# i66 step19 grad_mag: 2.368619 norm loss: 0.045007 oldest state: 80
# i67 step19 grad_mag: 1.969007 norm loss: 0.051883 oldest state: 80
# i68 step19 grad_mag: 2.160031 norm loss: 0.092278 oldest state: 80
# i69 step19 grad_mag: 1.778651 norm loss: 0.098806 oldest state: 80
# i70 step19 grad_mag: 2.095288 norm loss: 0.132909 oldest state: 80
# i71 step19 grad_mag: 2.047131 norm loss: 0.069003 oldest state: 80
# i72 step19 grad_mag: 1.950803 norm loss: 0.046858 oldest state: 80
# i73 step19 grad_mag: 2.278039 norm loss: 0.031143 oldest state: 80
# i74 step19 grad_mag: 2.287024 norm loss: 0.024477 oldest state: 80
# i75 step19 grad_mag: 2.411888 norm loss: 0.017980 oldest state: 80
# i76 step19 grad_mag: 2.249346 norm loss: 0.016360 oldest state: 80
# i77 step19 grad_mag: 2.652533 norm loss: 0.020829 oldest state: 80
# i78 step19 grad_mag: 3.111276 norm loss: 0.046571 oldest state: 80
# i79 step19 grad_mag: 2.685754 norm loss: 0.084115 oldest state: 80
# i80 step19 grad_mag: 2.677875 norm loss: 0.358645 oldest state: 100
# i81 step19 grad_mag: 3.280509 norm loss: 0.343866 oldest state: 100
# i82 step19 grad_mag: 3.014012 norm loss: 0.196309 oldest state: 100
# i83 step19 grad_mag: 3.453841 norm loss: 0.140881 oldest state: 100
# i84 step19 grad_mag: 3.148978 norm loss: 0.049801 oldest state: 100
# i85 step19 grad_mag: 2.783329 norm loss: 0.026380 oldest state: 100
# i86 step19 grad_mag: 2.720722 norm loss: 0.029244 oldest state: 100
# i87 step19 grad_mag: 2.824599 norm loss: 0.042553 oldest state: 100
# i88 step19 grad_mag: 2.993197 norm loss: 0.067522 oldest state: 100
# i89 step19 grad_mag: 3.206530 norm loss: 0.121237 oldest state: 100
# i90 step19 grad_mag: 3.511086 norm loss: 0.305564 oldest state: 100
# i91 step19 grad_mag: 3.306537 norm loss: 0.419327 oldest state: 100
# i92 step19 grad_mag: 4.437530 norm loss: 0.410487 oldest state: 100
# i93 step19 grad_mag: 4.266703 norm loss: 0.385216 oldest state: 100
# i94 step19 grad_mag: 4.011249 norm loss: 0.302889 oldest state: 100
# i95 step19 grad_mag: 3.952274 norm loss: 0.201409 oldest state: 100
# i96 step19 grad_mag: 3.646142 norm loss: 0.190579 oldest state: 100
# i97 step19 grad_mag: 4.722260 norm loss: 0.180546 oldest state: 100
# i98 step19 grad_mag: 4.981986 norm loss: 0.165427 oldest state: 100
# i99 step19 grad_mag: 3.974258 norm loss: 0.216135 oldest state: 100
# i100 step19 grad_mag: 4.031084 norm loss: 0.389183 oldest state: 120
# i101 step19 grad_mag: 3.956856 norm loss: 0.315976 oldest state: 120
# i102 step19 grad_mag: 4.937057 norm loss: 0.116864 oldest state: 120
# i103 step19 grad_mag: 4.683108 norm loss: 0.110450 oldest state: 120
# i104 step19 grad_mag: 4.528544 norm loss: 0.114030 oldest state: 120
# i105 step19 grad_mag: 4.769032 norm loss: 0.142978 oldest state: 120
# i106 step19 grad_mag: 4.886140 norm loss: 0.158619 oldest state: 120
# i107 step19 grad_mag: 5.061036 norm loss: 0.136059 oldest state: 120
# i108 step19 grad_mag: 5.561771 norm loss: 0.120004 oldest state: 120
# i109 step19 grad_mag: 4.849221 norm loss: 0.136719 oldest state: 120
# i110 step19 grad_mag: 6.740249 norm loss: 0.243973 oldest state: 120
# i111 step19 grad_mag: 4.900848 norm loss: 0.392122 oldest state: 120
# i112 step19 grad_mag: 7.068880 norm loss: 0.735315 oldest state: 120
# i113 step19 grad_mag: 6.002305 norm loss: 0.506409 oldest state: 120
# i114 step19 grad_mag: 5.503478 norm loss: 0.282627 oldest state: 120
# i115 step19 grad_mag: 4.693176 norm loss: 0.185339 oldest state: 120
# i116 step19 grad_mag: 5.009337 norm loss: 0.133427 oldest state: 120
# i117 step19 grad_mag: 5.065614 norm loss: 0.075738 oldest state: 120
# i118 step19 grad_mag: 4.844899 norm loss: 0.059142 oldest state: 120
# i119 step19 grad_mag: 5.633229 norm loss: 0.044978 oldest state: 120
# i120 step19 grad_mag: 5.114613 norm loss: 0.040854 oldest state: 140
# i121 step19 grad_mag: 5.090616 norm loss: 0.051479 oldest state: 140
# i122 step19 grad_mag: 6.400486 norm loss: 0.071784 oldest state: 140
# i123 step19 grad_mag: 7.051593 norm loss: 0.100736 oldest state: 140
# i124 step19 grad_mag: 5.026149 norm loss: 0.094013 oldest state: 140
# i125 step19 grad_mag: 5.528437 norm loss: 0.127869 oldest state: 140
# i126 step19 grad_mag: 6.730791 norm loss: 0.102688 oldest state: 120
# i127 step19 grad_mag: 8.688606 norm loss: 0.171190 oldest state: 140
# i128 step19 grad_mag: 7.467384 norm loss: 0.195562 oldest state: 140
# i129 step19 grad_mag: 7.856116 norm loss: 0.223814 oldest state: 140
# i130 step19 grad_mag: 8.423011 norm loss: 0.218541 oldest state: 140
# i131 step19 grad_mag: 7.937673 norm loss: 0.134289 oldest state: 140
# i132 step19 grad_mag: 7.757560 norm loss: 0.300520 oldest state: 140
# i133 step19 grad_mag: 8.205432 norm loss: 0.938366 oldest state: 140
# i134 step19 grad_mag: 7.539818 norm loss: 0.438419 oldest state: 140
# i135 step19 grad_mag: 6.683319 norm loss: 0.057298 oldest state: 140
# i136 step19 grad_mag: 6.692770 norm loss: 0.052478 oldest state: 140
# i137 step19 grad_mag: 7.072884 norm loss: 0.059980 oldest state: 140
# i138 step19 grad_mag: 6.673889 norm loss: 0.046671 oldest state: 140
# i139 step19 grad_mag: 7.563507 norm loss: 0.065396 oldest state: 140
# i140 step19 grad_mag: 9.113904 norm loss: 0.182358 oldest state: 160
# i141 step19 grad_mag: 11.537251 norm loss: 1.005835 oldest state: 160
# i142 step19 grad_mag: 9.256296 norm loss: 4.978357 oldest state: 160
# i143 step19 grad_mag: 8.639930 norm loss: 4.383814 oldest state: 160
# i144 step19 grad_mag: 9.018635 norm loss: 1.343829 oldest state: 160
# i145 step19 grad_mag: 9.968951 norm loss: 4.642007 oldest state: 160
# i146 step19 grad_mag: 7.716067 norm loss: 2.203650 oldest state: 160
# i147 step19 grad_mag: 8.887632 norm loss: 1.211182 oldest state: 160
# i148 step19 grad_mag: 10.773832 norm loss: 0.268962 oldest state: 160
# i149 step19 grad_mag: 8.025783 norm loss: 0.082516 oldest state: 160
# i150 step19 grad_mag: 8.894991 norm loss: 0.091169 oldest state: 160
# i151 step19 grad_mag: 9.545469 norm loss: 0.127521 oldest state: 160
# i152 step19 grad_mag: 9.179289 norm loss: 0.150131 oldest state: 160
# i153 step19 grad_mag: 8.828988 norm loss: 0.170834 oldest state: 140
# i154 step19 grad_mag: 9.025314 norm loss: 0.219691 oldest state: 160
# i155 step19 grad_mag: 11.000757 norm loss: 0.267974 oldest state: 160
# i156 step19 grad_mag: 12.287652 norm loss: 0.338095 oldest state: 140
# i157 step19 grad_mag: 12.846454 norm loss: 0.718578 oldest state: 160
# i158 step19 grad_mag: 12.158600 norm loss: 1.820324 oldest state: 160
# i159 step19 grad_mag: 10.366005 norm loss: 0.993965 oldest state: 160
# i160 step19 grad_mag: 14.172939 norm loss: 1.261322 oldest state: 180
# i161 step19 grad_mag: 12.247367 norm loss: 0.547052 oldest state: 180
# i162 step19 grad_mag: 12.734943 norm loss: 0.201872 oldest state: 180
# i163 step19 grad_mag: 13.282900 norm loss: 0.229051 oldest state: 180
# i164 step19 grad_mag: 10.704641 norm loss: 0.186694 oldest state: 180
# i165 step19 grad_mag: 9.318235 norm loss: 0.230537 oldest state: 180
# i166 step19 grad_mag: 11.196233 norm loss: 0.288383 oldest state: 180
# i167 step19 grad_mag: 9.814548 norm loss: 0.321899 oldest state: 180
# i168 step19 grad_mag: 13.880016 norm loss: 0.309859 oldest state: 180
# i169 step19 grad_mag: 13.063771 norm loss: 0.309849 oldest state: 180
# i170 step19 grad_mag: 10.392646 norm loss: 0.278446 oldest state: 180
# i171 step19 grad_mag: 11.436605 norm loss: 0.214282 oldest state: 180
# i172 step19 grad_mag: 12.890015 norm loss: 0.171464 oldest state: 180
# i173 step19 grad_mag: 12.893104 norm loss: 0.160324 oldest state: 180
# i174 step19 grad_mag: 11.576362 norm loss: 0.122337 oldest state: 160
# i175 step19 grad_mag: 15.834426 norm loss: 0.135535 oldest state: 180
# i176 step19 grad_mag: 13.401026 norm loss: 0.189135 oldest state: 180
# i177 step19 grad_mag: 13.049416 norm loss: 0.095076 oldest state: 140
# i178 step19 grad_mag: 13.098825 norm loss: 0.131737 oldest state: 160
# i179 step19 grad_mag: 16.348373 norm loss: 0.242249 oldest state: 180
# i180 step19 grad_mag: 11.767946 norm loss: 0.356571 oldest state: 200
# i181 step19 grad_mag: 10.386715 norm loss: 0.254345 oldest state: 200
# i182 step19 grad_mag: 16.839202 norm loss: 0.203113 oldest state: 200
# i183 step19 grad_mag: 15.113440 norm loss: 0.170933 oldest state: 200
# i184 step19 grad_mag: 13.997111 norm loss: 0.164005 oldest state: 180
# i185 step19 grad_mag: 17.311063 norm loss: 0.193639 oldest state: 200
# i186 step19 grad_mag: 14.084390 norm loss: 0.211921 oldest state: 180
# i187 step19 grad_mag: 13.274688 norm loss: 0.181470 oldest state: 200
# i188 step19 grad_mag: 18.503041 norm loss: 0.139456 oldest state: 200
# i189 step19 grad_mag: 18.705520 norm loss: 0.125722 oldest state: 200
# i190 step19 grad_mag: 17.221456 norm loss: 0.146226 oldest state: 200
# i191 step19 grad_mag: 18.783510 norm loss: 0.234651 oldest state: 200
# i192 step19 grad_mag: 17.392037 norm loss: 0.653198 oldest state: 200
# i193 step19 grad_mag: 16.862935 norm loss: 2.294154 oldest state: 200
# i194 step19 grad_mag: 11.146999 norm loss: 7.053533 oldest state: 200
# i195 step19 grad_mag: 10.722151 norm loss: 7.033783 oldest state: 180
# i196 step19 grad_mag: 17.079762 norm loss: 1.807780 oldest state: 200
# i197 step19 grad_mag: 17.131724 norm loss: 0.423838 oldest state: 200
# i198 step19 grad_mag: 18.495793 norm loss: 0.277442 oldest state: 200
# i199 step19 grad_mag: 19.921719 norm loss: 0.215027 oldest state: 180
# i200 step19 grad_mag: 19.494021 norm loss: 0.316868 oldest state: 200
# i201 step19 grad_mag: 16.452833 norm loss: 0.423181 oldest state: 220
# i202 step19 grad_mag: 20.445732 norm loss: 0.254265 oldest state: 220
# i203 step19 grad_mag: 21.253203 norm loss: 0.366479 oldest state: 220
# i204 step19 grad_mag: 17.823455 norm loss: 0.749541 oldest state: 220
# i205 step19 grad_mag: 14.688378 norm loss: 6.146337 oldest state: 220
# i206 step19 grad_mag: 13.525311 norm loss: 20.625512 oldest state: 220
# i207 step19 grad_mag: 13.630822 norm loss: 5.607173 oldest state: 220
# i208 step19 grad_mag: 16.174618 norm loss: 0.472492 oldest state: 220
# i209 step19 grad_mag: 17.084698 norm loss: 0.340595 oldest state: 220
# i210 step19 grad_mag: 15.163589 norm loss: 0.419100 oldest state: 220
# i211 step19 grad_mag: 13.280307 norm loss: 0.411454 oldest state: 200
# i212 step19 grad_mag: 13.929451 norm loss: 0.880935 oldest state: 220
# i213 step19 grad_mag: 15.135547 norm loss: 1.468300 oldest state: 220
# i214 step19 grad_mag: 16.499722 norm loss: 2.785889 oldest state: 220
# i215 step19 grad_mag: 19.520272 norm loss: 2.879155 oldest state: 220
# i216 step19 grad_mag: 18.283234 norm loss: 3.882268 oldest state: 220
# i217 step19 grad_mag: 19.002889 norm loss: 3.106050 oldest state: 220
# i218 step19 grad_mag: 14.688575 norm loss: 9.645004 oldest state: 220
# i219 step19 grad_mag: 15.264965 norm loss: 6.483244 oldest state: 220
# i220 step19 grad_mag: 18.540316 norm loss: 8.454133 oldest state: 240
# i221 step19 grad_mag: 16.569162 norm loss: 5.319399 oldest state: 240
# i222 step19 grad_mag: 17.049836 norm loss: 0.700122 oldest state: 240
# i223 step19 grad_mag: 12.913801 norm loss: 0.306042 oldest state: 240
# i224 step19 grad_mag: 15.316103 norm loss: 0.273048 oldest state: 240
# i225 step19 grad_mag: 16.668733 norm loss: 0.254205 oldest state: 240
# i226 step19 grad_mag: 16.834669 norm loss: 0.262378 oldest state: 240
# i227 step19 grad_mag: 18.970369 norm loss: 0.283707 oldest state: 220
# i228 step19 grad_mag: 18.810257 norm loss: 0.300373 oldest state: 240
# i229 step19 grad_mag: 20.065955 norm loss: 0.369406 oldest state: 240
# i230 step19 grad_mag: 21.219870 norm loss: 0.590958 oldest state: 240
# i231 step19 grad_mag: 18.048740 norm loss: 1.414737 oldest state: 240
# i232 step19 grad_mag: 16.711594 norm loss: 4.587639 oldest state: 220
# i233 step19 grad_mag: 14.917573 norm loss: 15.755256 oldest state: 240
# i234 step19 grad_mag: 12.169080 norm loss: 27.648411 oldest state: 240
# i235 step19 grad_mag: 9.117796 norm loss: 12.813474 oldest state: 220
# i236 step19 grad_mag: 17.800296 norm loss: 3.590721 oldest state: 240
# i237 step19 grad_mag: 18.058547 norm loss: 3.017197 oldest state: 240
# i238 step19 grad_mag: 12.873448 norm loss: 0.918223 oldest state: 240
# i239 step19 grad_mag: 13.084958 norm loss: 0.262064 oldest state: 240
# i240 step19 grad_mag: 18.238639 norm loss: 0.659749 oldest state: 260
# i241 step19 grad_mag: 20.311651 norm loss: 0.522895 oldest state: 240
# i242 step19 grad_mag: 22.760213 norm loss: 3.228958 oldest state: 260
# i243 step19 grad_mag: 17.951852 norm loss: 7.610136 oldest state: 260
# i244 step19 grad_mag: 17.320362 norm loss: 3.904924 oldest state: 240
# i245 step19 grad_mag: 17.784846 norm loss: 6.108659 oldest state: 260
# i246 step19 grad_mag: 18.817752 norm loss: 1.090612 oldest state: 260
# i247 step19 grad_mag: 21.328877 norm loss: 0.420197 oldest state: 240
# i248 step19 grad_mag: 16.814526 norm loss: 0.430330 oldest state: 260
# i249 step19 grad_mag: 20.425631 norm loss: 0.403377 oldest state: 260
# i250 step19 grad_mag: 19.179867 norm loss: 0.615796 oldest state: 260

# %%
show(ca.to_rgb(state)[0].detach())

# %%
ca.to_rgb(state)[0].mean()

# %%
#del ca, state, loss, opt, new_loss

# %%
#del sd_sds

# %%
import gc
for obj in gc.get_objects():
    try:
        if torch.is_tensor(obj) or (hasattr(obj, 'data') and torch.is_tensor(obj.data)):
            if torch.numel(obj) > 1024*1024*32: 
                print(type(obj), obj.size())
                #print(obj)
            
    except:
        pass
# Out:
# <class 'torch.nn.parameter.Parameter'> torch.Size([49408, 1024])
# <class 'torch.Tensor'> torch.Size([256, 12, 128, 128])
# <class 'torch.Tensor'> torch.Size([1, 128, 513, 513])
# <class 'torch.Tensor'> torch.Size([1, 128, 513, 513])
# <class 'torch.Tensor'> torch.Size([1, 128, 513, 513])
# /home/pwhiddy/mambaforge-pypy3/envs/py10/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:283: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn(

# %%
#torch.cuda.empty_cache()

# %%
torch.cuda.memory_allocated()
# Out:
# 18846907392

# %%
def zoom(img, scale=4):
  img = np.repeat(img, scale, 0)
  img = np.repeat(img, scale, 1)
  return img

class VideoWriter:
  def __init__(self, filename='_autoplay.mp4', fps=30.0, **kw):
    self.writer = None
    self.params = dict(filename=filename, fps=fps, **kw)

  def add(self, img):
    img = np.asarray(img)
    if self.writer is None:
      h, w = img.shape[:2]
      self.writer = FFMPEG_VideoWriter(size=(w, h), **self.params)
    if img.dtype in [np.float32, np.float64]:
      img = np.uint8(img.clip(0, 1)*255)
    if len(img.shape) == 2:
      img = np.repeat(img[..., None], 3, -1)
    self.writer.write_frame(img)

  def close(self):
    if self.writer:
      self.writer.close()

  def __enter__(self):
    return self

  def __exit__(self, *kw):
    self.close()
    if self.params['filename'] == '_autoplay.mp4':
      self.show()

  def show(self, **kw):
      self.close()
      fn = self.params['filename']
      display(mvp.ipython_display(fn, **kw))

class LoopWriter(VideoWriter):
  def __init__(self, *a, fade_len=1.0, **kw):
    super().__init__(*a, **kw)
    self._intro = []
    self._outro = []
    self.fade_len = int(fade_len*self.params['fps'])

  def add(self, img):
    if len(self._intro) < self.fade_len:
      self._intro.append(img)
      return
    self._outro.append(img)
    if len(self._outro) > self.fade_len:
      super().add(self._outro.pop(0))
  
  def close(self):
    for t in np.linspace(0, 1, len(self._intro)):
      img = self._intro.pop(0)*t + self._outro.pop(0)*(1.0-t)
      super().add(img)
    super().close()

# %%
step_n = 1
with torch.no_grad():
    with LoopWriter('final_ca.mp4', fade_len=0.0) as vid, torch.no_grad():
        x = m_state()["state"]
        #x[:] = 0.0
        #x[:,:,100, 100] = 1.0
        for k in tnrange(600, leave=False):
            img = ca.to_rgb(x)[0].detach().permute(1,2,0).cpu().numpy()
            #print(img.mean())
            vid.add(zoom(img, 2))
            #print(norm_loss(x, 1))
            #step_n = int(min(2**(k/30), 8))
            for i in range(step_n):
                x = x + ca(x)
    vid.show()
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
img.mean()
# Out:
# 14934.515

# %%
norm_loss(x, 1)
# Out:
# tensor(3.4056e+16, device='cuda:0')

# %%
del ca, state, loss, opt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 del ca, state, loss, opt, opt_t
#
# NameError: name 'ca' is not defined

# %%
x = torch.randn(1,12,128,128, device=device)
for i in range(100):
    x = x + ca(x)
